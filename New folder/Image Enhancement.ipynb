# %%
#Ekstrasi Fitur

# %%
from PIL import Image

# %matplotlib inline  

#Import an image
image = Image.open("a.jpg")

image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=837x699 at 0x28B7CF99C88>

# %%
im = image.convert('L')
im
# Out:
# <PIL.Image.Image image mode=L size=837x699 at 0x2BB6D8549C8>

# %%
array(im)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-c6624f6dcb44> in <module>
# ----> 1 array(im)
#
# TypeError: array() argument 1 must be a unicode character, not Image

# %%
from PIL import *

figure()
p = image.convert("L").filter(ImageFilter.GaussianBlur(radius = 2))
p.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-1a18e1457e4b> in <module>
#       1 from PIL import *
#       2
# ----> 3 figure()
#       4 p = image.convert("L").filter(ImageFilter.GaussianBlur(radius = 2))
#       5 p.show()
#
# NameError: name 'figure' is not defined

# %%
#Intesity Adjustment

# %%
import cv2 
import numpy as np 
  
# Open the image. 
img = cv2.imread('a.jpg') 
  
# Trying 4 gamma values. 
for gamma in [1.2]: 
      
    # Apply gamma correction. 
    gamma_corrected = np.array(255*(img / 255) ** gamma, dtype = 'uint8') 
  
    # Save edited images. 
    cv2.imwrite('a Intensity'+str(gamma)+'.jpg', gamma_corrected)

# %%
import cv2 
import numpy as np 
  
# Open the image. 
img = cv2.imread('b.jpg') 
  
# Trying 4 gamma values. 
for gamma in [1.2]: 
      
    # Apply gamma correction. 
    gamma_corrected = np.array(255*(img / 255) ** gamma, dtype = 'uint8') 
  
    # Save edited images. 
    cv2.imwrite('b Intensity'+str(gamma)+'.jpg', gamma_corrected)

# %%
import cv2 
import numpy as np 
  
# Open the image. 
img = cv2.imread('c.jpg') 
  
# Trying 4 gamma values. 
for gamma in [1.2]: 
      
    # Apply gamma correction. 
    gamma_corrected = np.array(255*(img / 255) ** gamma, dtype = 'uint8') 
  
    # Save edited images. 
    cv2.imwrite('c Intensity'+str(gamma)+'.jpg', gamma_corrected)

# %%
# Histogram Equalization

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('a.jpg',0)

# create a CLAHE object (Arguments are optional).
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)

cv2.imwrite('a-Histogram.jpg',cl1)
# Out:
# True

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('b.jpg',0)

# create a CLAHE object (Arguments are optional).
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)

cv2.imwrite('b-Histogram.jpg',cl1)
# Out:
# True

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('c.jpg',0)

# create a CLAHE object (Arguments are optional).
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(img)

cv2.imwrite('c-Histogram.jpg',cl1)
# Out:
# True

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('c.jpg',0)
ret,thresh3 = cv2.threshold(img,130,255,cv2.THRESH_TRUNC)

thresh = ['thresh3']

for i in range(1):
    plt.subplot(1,1,i+1),plt.imshow(eval(thresh[i]),'gray')
    plt.title(thresh[i])

plt.show()
